# %%
import numpy as np
import pandas as pd
import os
import cv2

# %%
a = pd.read_csv('data/train_labels.csv')

# %%
a
# Out:
#              frame  xmin  xmax  ymin  ymax  class_id
# 0        80000.jpg   148   194    23    44         1
# 1        80000.jpg   149   164    51    68         2
# 2        80000.jpg   205   220    48    65         3
# 3        80000.jpg   149   178    74    90         4
# 4        80000.jpg   192   205    73    88         5
# 5        80000.jpg   218   233    72    88         6
# 6        80000.jpg   149   270    95   130         7
# 7        80000.jpg   190   354   148   173         8
# 8        80001.jpg   144   188   130   146         1
# 9        80001.jpg   146   160   151   163         2
# 10       80001.jpg   199   213   147   160         3
# 11       80001.jpg   147   174   167   179         4
# 12       80001.jpg   186   200   165   176         5
# 13       80001.jpg   211   226   164   175         6
# 14       80001.jpg   147   261   179   207         7
# 15       80001.jpg   188   341   215   237         8
# 16       80002.jpg   154   196    30    58         1
# ...

# %%
a = a[['frame', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id']]

# %%
a
# Out:
#              frame  xmin  xmax  ymin  ymax  class_id
# 0        80000.jpg   148   194    23    44         1
# 1        80000.jpg   149   164    51    68         2
# 2        80000.jpg   205   220    48    65         3
# 3        80000.jpg   149   178    74    90         4
# 4        80000.jpg   192   205    73    88         5
# 5        80000.jpg   218   233    72    88         6
# 6        80000.jpg   149   270    95   130         7
# 7        80000.jpg   190   354   148   173         8
# 8        80001.jpg   144   188   130   146         1
# 9        80001.jpg   146   160   151   163         2
# 10       80001.jpg   199   213   147   160         3
# 11       80001.jpg   147   174   167   179         4
# 12       80001.jpg   186   200   165   176         5
# 13       80001.jpg   211   226   164   175         6
# 14       80001.jpg   147   261   179   207         7
# 15       80001.jpg   188   341   215   237         8
# 16       80002.jpg   154   196    30    58         1
# ...

# %%
b = a['xmax'].copy()

# %%
c = a['ymin'].copy()

# %%
a['xmax'] = c.values

# %%
a['ymin'] = b.values

# %%
all(a['xmin'] < a['xmax'])
# Out:
# True

# %%
all(a['ymin'] < a['ymax'])
# Out:
# True

# %%
a.to_csv('data/train_labels.csv', index=False)

# %%
a = pd.read_csv('data/val_labels.csv')

# %%
a
# Out:
#             frame  xmin  xmax  ymin  ymax  class_id
# 0      152000.jpg   155   195   120   134         1
# 1      152000.jpg   156   169   138   149         2
# 2      152000.jpg   205   218   135   146         3
# 3      152000.jpg   157   182   153   163         4
# 4      152000.jpg   194   206   152   161         5
# 5      152000.jpg   217   231   150   160         6
# 6      152000.jpg   158   263   164   189         7
# 7      152000.jpg   195   337   196   215         8
# 8      152001.jpg   157   201    81   106         1
# 9      152001.jpg   158   173   114   133         2
# 10     152001.jpg   212   227   109   129         3
# 11     152001.jpg   158   186   140   159         4
# 12     152001.jpg   200   213   139   156         5
# 13     152001.jpg   225   240   136   155         6
# 14     152001.jpg   159   276   162   204         7
# 15     152001.jpg   200   358   221   253         8
# 16     152002.jpg   150   194    54    73         1
# ...

# %%
a = a[['frame', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id']]

# %%
a
# Out:
#             frame  xmin  xmax  ymin  ymax  class_id
# 0      152000.jpg   155   195   120   134         1
# 1      152000.jpg   156   169   138   149         2
# 2      152000.jpg   205   218   135   146         3
# 3      152000.jpg   157   182   153   163         4
# 4      152000.jpg   194   206   152   161         5
# 5      152000.jpg   217   231   150   160         6
# 6      152000.jpg   158   263   164   189         7
# 7      152000.jpg   195   337   196   215         8
# 8      152001.jpg   157   201    81   106         1
# 9      152001.jpg   158   173   114   133         2
# 10     152001.jpg   212   227   109   129         3
# 11     152001.jpg   158   186   140   159         4
# 12     152001.jpg   200   213   139   156         5
# 13     152001.jpg   225   240   136   155         6
# 14     152001.jpg   159   276   162   204         7
# 15     152001.jpg   200   358   221   253         8
# 16     152002.jpg   150   194    54    73         1
# ...

# %%
b = a['xmax'].copy()

# %%
c = a['ymin'].copy()

# %%
a['xmax'] = c.values

# %%
a['ymin'] = b.values

# %%
all(a['xmin'] < a['xmax'])
# Out:
# True

# %%
all(a['ymin'] < a['ymax'])
# Out:
# True

# %%
a.to_csv('data/val_labels.csv', index=False)

# %%
a
# Out:
#             frame  xmin  xmax  ymin  ymax  class_id
# 0      152000.jpg   155   195   120   134         1
# 1      152000.jpg   156   169   138   149         2
# 2      152000.jpg   205   218   135   146         3
# 3      152000.jpg   157   182   153   163         4
# 4      152000.jpg   194   206   152   161         5
# 5      152000.jpg   217   231   150   160         6
# 6      152000.jpg   158   263   164   189         7
# 7      152000.jpg   195   337   196   215         8
# 8      152001.jpg   157   201    81   106         1
# 9      152001.jpg   158   173   114   133         2
# 10     152001.jpg   212   227   109   129         3
# 11     152001.jpg   158   186   140   159         4
# 12     152001.jpg   200   213   139   156         5
# 13     152001.jpg   225   240   136   155         6
# 14     152001.jpg   159   276   162   204         7
# 15     152001.jpg   200   358   221   253         8
# 16     152002.jpg   150   194    54    73         1
# ...
